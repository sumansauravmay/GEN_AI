# %% [markdown]
# <a href="https://colab.research.google.com/github/sumansauravmay/GEN_AI/blob/main/Basic_tokennization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str="i am running and he is not running"
newList=list(str)
print(newList)
# Out:
# ['i', ' ', 'a', 'm', ' ', 'r', 'u', 'n', 'n', 'i', 'n', 'g', ' ', 'a', 'n', 'd', ' ', 'h', 'e', ' ', 'i', 's', ' ', 'n', 'o', 't', ' ', 'r', 'u', 'n', 'n', 'i', 'n', 'g']

# %%
arr=str.split()

# %%
print(set(arr))
# Out:
# {'is', 'am', 'running', 'i', 'and', 'not', 'he'}

# %%
freq={}
for w in arr:
  if w in freq:
    freq[w]+=1
  else:
    freq[w]=1

print(freq)
# Out:
# {'i': 1, 'am': 1, 'running': 2, 'and': 1, 'he': 1, 'is': 1, 'not': 1}

# %%
from typing import Counter
print(Counter(arr))
# Out:
# Counter({'running': 2, 'i': 1, 'am': 1, 'and': 1, 'he': 1, 'is': 1, 'not': 1})
